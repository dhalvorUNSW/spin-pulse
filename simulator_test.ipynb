# %%
import numpy as np
from pulses import cw_pulse, PulseSequence

p = cw_pulse(2e-9, 2*np.pi*50e6)
sequence = PulseSequence()
sequence.add_pulse(p)
sequence.add_pause(1e-9)
sequence.gaussian_filter()
sequence.plot_pulse()

# %%
a = np.arange(1e-9, 101e-9, 1e-9)
